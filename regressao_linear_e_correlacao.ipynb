# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('dados/dados.csv')
dados.head()
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %%
ax = sns.boxplot(x='Renda', y= 'Anos de Estudo', data=dados.query('Renda <5000'), orient='h')

# %%
dados.corr()
# Out:
#                       UF      Sexo     Idade       Cor  Anos de Estudo  \
# UF              1.000000  0.001479  0.019818 -0.252820        0.123380
# Sexo            0.001479  1.000000  0.002994 -0.003193        0.115662
# Idade           0.019818  0.002994  1.000000 -0.058952       -0.267614
# Cor            -0.252820 -0.003193 -0.058952  1.000000       -0.173609
# Anos de Estudo  0.123380  0.115662 -0.267614 -0.173609        1.000000
# Renda           0.127939 -0.086826  0.041357 -0.151921        0.332152
# Altura         -0.000552  0.001315 -0.001470 -0.002849        0.003817
#
#                    Renda    Altura
# UF              0.127939 -0.000552
# Sexo           -0.086826  0.001315
# Idade           0.041357 -0.001470
# Cor            -0.151921 -0.002849
# Anos de Estudo  0.332152  0.003817
# Renda           1.000000 -0.004073
# Altura         -0.004073  1.000000
